# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# # Making a Bar graph

# %%
x = np.random.rand(10, 4)
x
# Out:
# array([[0.75285095, 0.11541853, 0.23480418, 0.23213046],
#        [0.61504857, 0.49275495, 0.24635694, 0.07621296],
#        [0.00614072, 0.12735526, 0.92846976, 0.79431451],
#        [0.88456764, 0.93807271, 0.36669457, 0.48020273],
#        [0.9671681 , 0.3321663 , 0.65083434, 0.30907346],
#        [0.41541754, 0.80462859, 0.17504535, 0.815322  ],
#        [0.79068356, 0.38499587, 0.86697483, 0.43659116],
#        [0.77616206, 0.93255499, 0.70762111, 0.32252599],
#        [0.58667824, 0.12964556, 0.28707232, 0.38323859],
#        [0.80598352, 0.39027743, 0.14765459, 0.65562299]])

# %% [markdown]
# Turn it into a DataFrame

# %%
df = pd.DataFrame(x, columns=['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0  0.752851  0.115419  0.234804  0.232130
# 1  0.615049  0.492755  0.246357  0.076213
# 2  0.006141  0.127355  0.928470  0.794315
# 3  0.884568  0.938073  0.366695  0.480203
# 4  0.967168  0.332166  0.650834  0.309073
# 5  0.415418  0.804629  0.175045  0.815322
# 6  0.790684  0.384996  0.866975  0.436591
# 7  0.776162  0.932555  0.707621  0.322526
# 8  0.586678  0.129646  0.287072  0.383239
# 9  0.805984  0.390277  0.147655  0.655623

# %% [markdown]
# # One way to plot:

# %%
df.plot.bar();

# %% [markdown]
# # Other way to plot:

# %%
df.plot(kind='bar');

# %%
car_sales = pd.read_csv('car_sales_new.csv')
car_sales
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors  Price   Sale Date  \
# 0           0  Toyota  White         150043      4   4000  2021-06-30
# 1           1   Honda    Red          87899      4   5000  2021-07-01
# 2           2  Toyota   Blue          32549      3   7000  2021-07-02
# 3           3     BMW  Black          11179      5  22000  2021-07-03
# 4           4  Nissan  White         213095      4   3500  2021-07-04
# 5           5  Toyota  Green          99213      4   4500  2021-07-05
# 6           6   Honda   Blue          45698      4   7500  2021-07-06
# 7           7   Honda   Blue          54738      4   7000  2021-07-07
# 8           8  Toyota  White          60000      4   6250  2021-07-08
# 9           9  Nissan  White          31600      4   9700  2021-07-09
#
#    Total sales
# 0         4000
# 1         9000
# 2        16000
# 3        38000
# 4        41500
# 5        46000
# 6        53500
# 7        60500
# 8        66750
# 9        76450

# %%
car_sales.plot(x='Make', y='Odometer (KM)', kind='bar');

# %% [markdown]
# # Histograms

# %%
car_sales['Odometer (KM)'].plot.hist();

# %%
car_sales['Odometer (KM)'].plot(kind='hist');

# %%
car_sales['Odometer (KM)'].plot.hist(bins=20);

# %%
heart_disease = pd.read_csv('heart-disease.csv')
heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %% [markdown]
# Create a Histogram of the age column

# %%
heart_disease['age'].plot.hist();

# %% [markdown]
# # Subplots

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease.plot.hist(subplots=True);

# %%
heart_disease.plot.hist(figsize=(10, 30), subplots=True);

# %%
heart_disease.head().plot.hist();

# %% [markdown]
# # Which method to use? (pyplot or matplotlib OO method?)

# %% [markdown]
# * When plotting, something quickly, its ok to use the pyplot method.
# * When plotting, something more advanced use the OO method.

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
over_50 = heart_disease[heart_disease['age'] > 50]
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
len(over_50)
# Out:
# 208

# %% [markdown]
# # Pyplot method

# %%
over_50.plot(kind='scatter',
             x='age',
             y='chol',
             c='target');

# %% [markdown]
# # OO method

# %%
fig, ax = plt.subplots(figsize=(10, 6))
over_50.plot(kind='scatter',
             x='age',
             y='chol',
             c='target',
             ax=ax);

# %%
fig, ax = plt.subplots(figsize=(10, 6))
over_50.plot(kind='scatter',
             x='age',
             y='chol',
             c='target',
             ax=ax);

ax.set_xlim([45, 100]);

# %% [markdown]
# # OO method from scratch

# %%
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the Data

scatter = ax.scatter(x=over_50['age'],
                     y=over_50['chol'],
                     c=over_50['target']);

# %% [markdown]
# Customise the plot

# %%
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the Data

scatter = ax.scatter(x=over_50['age'],
                     y=over_50['chol'],
                     c=over_50['target']);

# Customise

ax.set(title="Heart Disease and Cholesterol levels",
       xlabel="Age",
       ylabel="Cholesterol");

# %%
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the Data

scatter = ax.scatter(x=over_50['age'],
                     y=over_50['chol'],
                     c=over_50['target']);

# Customise

ax.set(title="Heart Disease and Cholesterol levels",
       xlabel="Age",
       ylabel="Cholesterol")

# Add a legend

ax.legend(*scatter.legend_elements(), title="Target");

# %%
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the Data

scatter = ax.scatter(x=over_50['age'],
                     y=over_50['chol'],
                     c=over_50['target']);

# Customise

ax.set(title="Heart Disease and Cholesterol levels",
       xlabel="Age",
       ylabel="Cholesterol")

# Add a legend

ax.legend(*scatter.legend_elements(), title="Target")

# Add a horizontal line

ax.axhline(over_50['chol'].mean());

# %%
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the Data

scatter = ax.scatter(x=over_50['age'],
                     y=over_50['chol'],
                     c=over_50['target']);

# Customise

ax.set(title="Heart Disease and Cholesterol levels",
       xlabel="Age",
       ylabel="Cholesterol")

# Add a legend

ax.legend(*scatter.legend_elements(), title="Target")

# Add a horizontal line

ax.axhline(over_50['chol'].mean(),
           linestyle='--');

# %% [markdown]
# # Subplot of chol, age, thalach

# %%
fig, (ax0, ax1) = plt.subplots(nrows=2,
                               ncols=1,
                               figsize=(10, 10))

# Add Data to ax0

scatter = ax0.scatter(x=over_50['age'],
                      y=over_50['chol'],
                      c=over_50['target'])

# Customise ax0

ax0.set(title='Heart Disease and Cholesterol Levels',
        xlabel='Age',
        ylabel='Cholesterol Levels')

ax0.legend(*scatter.legend_elements(), title='Target')

ax0.axhline(over_50['chol'].mean(),
            linestyle='--')

# Add Data to ax1

scatter = ax1.scatter(x=over_50['age'],
                      y=over_50['thalach'],
                      c=over_50['target'])

# Customise ax1

ax1.set(title='Heart Disease and Thalach',
        xlabel='Age',
        ylabel='Thalach')

ax1.legend(*scatter.legend_elements(), title='Target')

ax1.axhline(over_50['thalach'].mean(),
           linestyle='--')

# Add a title to the whole figure

fig.suptitle('Heart Disease Analysis', fontsize=16, fontweight='bold');

# %% [markdown]
# # Customisation

# %%
# see the different styles available

plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
car_sales['Price'].plot();

# %%
plt.style.use('seaborn-whitegrid')

# %%
car_sales['Price'].plot();

# %%
plt.style.use('Solarize_Light2')
car_sales['Price'].plot();

# %%
plt.style.use('_classic_test_patch')
car_sales['Price'].plot();

# %%
for x in plt.style.available:
    print(x)
    plt.style.use(x),
    car_sales['Price'].plot()
# Out:
# Solarize_Light2
# _classic_test_patch
# bmh
# classic
# dark_background
# fast
# fivethirtyeight
# ggplot
# grayscale
# seaborn
# seaborn-bright
# seaborn-colorblind
# seaborn-dark
# seaborn-dark-palette
# seaborn-darkgrid
# seaborn-deep
# seaborn-muted
# seaborn-notebook
# seaborn-paper
# seaborn-pastel
# seaborn-poster
# seaborn-talk
# seaborn-ticks
# seaborn-white
# seaborn-whitegrid
# tableau-colorblind10

# %%
fig = plt.figure(dpi=100, figsize=(10, 20), tight_layout=True)
available = ['default'] + plt.style.available
for i, style in enumerate(available):
    with plt.style.context(style):
        ax = fig.add_subplot(10, 3, i + 1)
        ax.plot(car_sales['Price'])
    ax.set_title(style)

# %%
plt.style.use('dark_background')
car_sales.plot(x='Odometer (KM)', y='Price', kind='scatter');
