# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# # Making a Bar graph

# %%
x = np.random.rand(10, 4)
x
# Out:
# array([[0.9274912 , 0.66200727, 0.49514718, 0.19464812],
#        [0.24051791, 0.14038591, 0.78242072, 0.28590966],
#        [0.29742885, 0.97839019, 0.76039566, 0.47535545],
#        [0.45789907, 0.56850851, 0.06471125, 0.52294892],
#        [0.48221358, 0.89381056, 0.54697747, 0.49691369],
#        [0.24921264, 0.68374593, 0.01173536, 0.58434985],
#        [0.06765435, 0.69811754, 0.37346228, 0.12361057],
#        [0.50305685, 0.19763123, 0.98594066, 0.90363608],
#        [0.70535491, 0.46913521, 0.68900014, 0.67989271],
#        [0.30062028, 0.76600161, 0.42143285, 0.26206649]])

# %% [markdown]
# Turn it into a DataFrame

# %%
df = pd.DataFrame(x, columns=['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0  0.927491  0.662007  0.495147  0.194648
# 1  0.240518  0.140386  0.782421  0.285910
# 2  0.297429  0.978390  0.760396  0.475355
# 3  0.457899  0.568509  0.064711  0.522949
# 4  0.482214  0.893811  0.546977  0.496914
# 5  0.249213  0.683746  0.011735  0.584350
# 6  0.067654  0.698118  0.373462  0.123611
# 7  0.503057  0.197631  0.985941  0.903636
# 8  0.705355  0.469135  0.689000  0.679893
# 9  0.300620  0.766002  0.421433  0.262066

# %% [markdown]
# # One way to plot:

# %%
df.plot.bar();

# %% [markdown]
# # Other way to plot:

# %%
df.plot(kind='bar');

# %%
car_sales = pd.read_csv('car_sales_new.csv')
car_sales
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors  Price   Sale Date  \
# 0           0  Toyota  White         150043      4   4000  2021-06-30
# 1           1   Honda    Red          87899      4   5000  2021-07-01
# 2           2  Toyota   Blue          32549      3   7000  2021-07-02
# 3           3     BMW  Black          11179      5  22000  2021-07-03
# 4           4  Nissan  White         213095      4   3500  2021-07-04
# 5           5  Toyota  Green          99213      4   4500  2021-07-05
# 6           6   Honda   Blue          45698      4   7500  2021-07-06
# 7           7   Honda   Blue          54738      4   7000  2021-07-07
# 8           8  Toyota  White          60000      4   6250  2021-07-08
# 9           9  Nissan  White          31600      4   9700  2021-07-09
#
#    Total sales
# 0         4000
# 1         9000
# 2        16000
# 3        38000
# 4        41500
# 5        46000
# 6        53500
# 7        60500
# 8        66750
# 9        76450

# %%
car_sales.plot(x='Make', y='Odometer (KM)', kind='bar');

# %% [markdown]
# # Histograms

# %%
car_sales['Odometer (KM)'].plot.hist();

# %%
car_sales['Odometer (KM)'].plot(kind='hist');

# %%
car_sales['Odometer (KM)'].plot.hist(bins=20);

# %%
heart_disease = pd.read_csv('heart-disease.csv')
heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %% [markdown]
# Create a Histogram of the age column

# %%
heart_disease['age'].plot.hist();

# %% [markdown]
# # Subplots

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease.plot.hist(subplots=True);

# %%
heart_disease.plot.hist(figsize=(10, 30), subplots=True);

# %%
heart_disease.head().plot.hist();

# %% [markdown]
# # Which method to use? (pyplot or matplotlib OO method?)

# %% [markdown]
# * When plotting, something quickly, its ok to use the pyplot method.
# * When plotting, something more advanced use the OO method.

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
over_50 = heart_disease[heart_disease['age'] > 50]
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
len(over_50)
# Out:
# 208

# %% [markdown]
# # Pyplot method

# %%
over_50.plot(kind='scatter',
             x='age',
             y='chol',
             c='target');

# %% [markdown]
# # OO method

# %%
fig, ax = plt.subplots(figsize=(10, 6))
over_50.plot(kind='scatter',
             x='age',
             y='chol',
             c='target',
             ax=ax);

# %%
fig, ax = plt.subplots(figsize=(10, 6))
over_50.plot(kind='scatter',
             x='age',
             y='chol',
             c='target',
             ax=ax);

ax.set_xlim([45, 100]);

# %% [markdown]
# # OO method from scratch

# %%
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the Data

scatter = ax.scatter(x=over_50['age'],
                     y=over_50['chol'],
                     c=over_50['target']);

# %% [markdown]
# Customise the plot

# %%
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the Data

scatter = ax.scatter(x=over_50['age'],
                     y=over_50['chol'],
                     c=over_50['target']);

# Customise

ax.set(title="Heart Disease and Cholesterol levels",
       xlabel="Age",
       ylabel="Cholesterol");

# %%
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the Data

scatter = ax.scatter(x=over_50['age'],
                     y=over_50['chol'],
                     c=over_50['target']);

# Customise

ax.set(title="Heart Disease and Cholesterol levels",
       xlabel="Age",
       ylabel="Cholesterol")

# Add a legend

ax.legend(*scatter.legend_elements(), title="Target");

# %%
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the Data

scatter = ax.scatter(x=over_50['age'],
                     y=over_50['chol'],
                     c=over_50['target']);

# Customise

ax.set(title="Heart Disease and Cholesterol levels",
       xlabel="Age",
       ylabel="Cholesterol")

# Add a legend

ax.legend(*scatter.legend_elements(), title="Target")

# Add a horizontal line

ax.axhline(over_50['chol'].mean());

# %%
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the Data

scatter = ax.scatter(x=over_50['age'],
                     y=over_50['chol'],
                     c=over_50['target']);

# Customise

ax.set(title="Heart Disease and Cholesterol levels",
       xlabel="Age",
       ylabel="Cholesterol")

# Add a legend

ax.legend(*scatter.legend_elements(), title="Target")

# Add a horizontal line

ax.axhline(over_50['chol'].mean(),
           linestyle='--');

# %% [markdown]
# # Subplot of chol, age, thalach

# %%
fig, (ax0, ax1) = plt.subplots(nrows=2,
                               ncols=1,
                               figsize=(10, 10))

# Add Data to ax0

scatter = ax0.scatter(x=over_50['age'],
                      y=over_50['chol'],
                      c=over_50['target'])

# Customise ax0

ax0.set(title='Heart Disease and Cholesterol Levels',
        xlabel='Age',
        ylabel='Cholesterol Levels')

ax0.legend(*scatter.legend_elements(), title='Target')

ax0.axhline(over_50['chol'].mean(),
            linestyle='--')

# Add Data to ax1

scatter = ax1.scatter(x=over_50['age'],
                      y=over_50['thalach'],
                      c=over_50['target'])

# Customise ax1

ax1.set(title='Heart Disease and Thalach',
        xlabel='Age',
        ylabel='Thalach')

ax1.legend(*scatter.legend_elements(), title='Target')

ax1.axhline(over_50['thalach'].mean(),
           linestyle='--')

# Add a title to the whole figure

fig.suptitle('Heart Disease Analysis', fontsize=16, fontweight='bold');

# %% [markdown]
# # Customisation

# %%
# see the different styles available

plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
car_sales['Price'].plot();

# %%
plt.style.use('seaborn-whitegrid')

# %%
car_sales['Price'].plot();

# %%
plt.style.use('Solarize_Light2')
car_sales['Price'].plot();

# %%
plt.style.use('_classic_test_patch')
car_sales['Price'].plot();

# %%
for x in plt.style.available:
    print(x)
    plt.style.use(x),
    car_sales['Price'].plot()
# Out:
# Solarize_Light2
# _classic_test_patch
# bmh
# classic
# dark_background
# fast
# fivethirtyeight
# ggplot
# grayscale
# seaborn
# seaborn-bright
# seaborn-colorblind
# seaborn-dark
# seaborn-dark-palette
# seaborn-darkgrid
# seaborn-deep
# seaborn-muted
# seaborn-notebook
# seaborn-paper
# seaborn-pastel
# seaborn-poster
# seaborn-talk
# seaborn-ticks
# seaborn-white
# seaborn-whitegrid
# tableau-colorblind10
